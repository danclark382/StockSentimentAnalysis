# %% [raw]
# #https://bhaskarvk.github.io/2015/01/how-to-use-twitters-search-rest-api-most-effectively./

# %%
import json
import os
import sys

import tweepy

# %%
with open("/Users/dclark171/projects/myKeys.json", 'r') as f:
    data = json.load(f)
twitter_keys = data['keys']['twitter']

# %%
CONSUMER_KEY = twitter_keys['CONSUMER_KEY']
CONSUMER_SECRET = twitter_keys['CONSUMER_SECRET']

# %%
auth = tweepy.AppAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

api = tweepy.API(auth, wait_on_rate_limit=True,
        wait_on_rate_limit_notify=True)

if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# %%
searchQuery = '#someHashtag'  
maxTweets = 10000000 
tweetsPerQry = 100  
fName = 'tweets.txt' 


# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None


max_id = -1L

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
with open(fName, 'w') as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1))
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json, unpicklable=False) +
                        '\n')
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
            # Just exit if any error
            print("some error : " + str(e))
            break

print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))

# %%
searchQuery = '$SPY'  # this is what we're searching for
maxTweets = 10000000 # Some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -1

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
all_tweets = []
while tweetCount < maxTweets:
    try:
        if (max_id <= 0):
            if (not sinceId):
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
            else:
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        since_id=sinceId)
        else:
            if (not sinceId):
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        max_id=str(max_id - 1))
            else:
                new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                        max_id=str(max_id - 1),
                                        since_id=sinceId)
        if not new_tweets:
            print("No more tweets found")
            break
        for tweet in new_tweets:
            all_tweets.append(tweet)
        tweetCount += len(new_tweets)
        print("Downloaded {0} tweets".format(tweetCount))
        max_id = new_tweets[-1].id
    except tweepy.TweepError as e:
        # Just exit if any error
        print("some error : " + str(e))
        break

print ("Downloaded {0} tweets".format(tweetCount))
# Out:
# Down
# Downloaded 12060 tweets
# Downloaded 12159 tweets
# Downloaded 12259 tweets
# Downloaded 12359 tweets
# Downloaded 12453 tweets
# Downloaded 12550 tweets
# Downloaded 12650 tweets
# Downloaded 12750 tweets
# Downloaded 12850 tweets
# Downloaded 12950 tweets
# Downloaded 13050 tweets
# Downloaded 13150 tweets
# Downloaded 13250 tweets
# Downloaded 13350 tweets
# Downloaded 13450 tweets
# Downloaded 13550 tweets
# Downloaded 13650 tweets
# Downloaded 13750 tweets
# Downloaded 13850 tweets
# Downloaded 13950 tweets
# Downloaded 14050 tweets
# Downloaded 14150 tweets
# Downloaded 14250 tweets
# Downloaded 14350 tweets
# Downloaded 14450 tweets
# Downloaded 14550 tweets
# Downloaded 14650 tweets
# Downloaded 14750 tweets
# Downloaded 14850 tweets
# Downloaded 14950 tweets
# Downloaded 15050 tweets
# Downloaded 15150 tweets
# Downloaded 15250 tweets
# Downloaded 15350 tweets
# Downloaded 15450 tweets
# Downloaded 15550 tweets
# Downloaded 15650 tweets
# Downloaded 15750 tweets
# Downloaded 15850 tweets
# Downloaded 15950 tweets
# Downloaded 16050 tweets
# Downloaded 16150 tweets
# Downloaded 16250 tweets
# Downloaded 16341 tweets
# Downloaded 16433 tweets
# Downloaded 16533 tweets
# Downloaded 16633 tweets
# Downloaded 16733 tweets
# Downloaded 16833 tweets
# Downloaded 16933 tweets
# Downloaded 17031 tweets
# Downloaded 17128 tweets
# Downloaded 17228 tweets
# Downloaded 17327 tweets
# Downloaded 17427 tweets
# Downloaded 17527 tweets
# Downloaded 17627 tweets
# Downloaded 17727 tweets
# Downloaded 17827 tweets
# Downloaded 17921 tweets
# Downloaded 18021 tweets
# Downloaded 18121 tweets
# Downloaded 18221 tweets
# Downloaded 18321 tweets
# Downloaded 18421 tweets
# Downloaded 18521 tweets
# Downloaded 18621 tweets
# Downloaded 18721 tweets
# Downloaded 18821 tweets
# Downloaded 18921 tweets
# Downloaded 19021 tweets
# Downloaded 19121 tweets
# Downloaded 19221 tweets
# Downloaded 19321 tweets
# Downloaded 19421 tweets
# Downloaded 19521 tweets
# Downloaded 19621 tweets
# Downloaded 19721 tweets
# Downloaded 19821 tweets
# Downloaded 19921 tweets
# Downloaded 20021 tweets
# Downloaded 20121 tweets
# Downloaded 20221 tweets
# Downloaded 20321 tweets
# Downloaded 20421 tweets
# Downloaded 20521 tweets
# Downloaded 20621 tweets
# Downloaded 20721 tweets
# Downloaded 20821 tweets
# Downloaded 20921 tweets
# Downloaded 21021 tweets
# Downloaded 21121 tweets
# Downloaded 21221 tweets
# Downloaded 21321 tweets
# Downloaded 21421 tweets
# Downloaded 21521 tweets
# Downloaded 21621 tweets
# Downloaded 21721 tweets
# Downloaded 21821 tweets
# Downloaded 21921 tweets
# Downloaded 22021 tweets
# Downloaded 22121 tweets
# Downloaded 22221 tweets
# Downloaded 22321 tweets
# Downloaded 22421 tweets
# Downloaded 22521 tweets
# Downloaded 22621 tweets
# Downloaded 22721 tweets
# Downloaded 22821 tweets
# Downloaded 22921 tweets
# Downloaded 23014 tweets
# Downloaded 23114 tweets
# Downloaded 23214 tweets
# Downloaded 23314 tweets
# Downloaded 23414 tweets
# Downloaded 23514 tweets
# Downloaded 23614 tweets
# Downloaded 23714 tweets
# Downloaded 23814 tweets
# Downloaded 23914 tweets
# Downloaded 24014 tweets
# Downloaded 24114 tweets
# Downloaded 24214 tweets
# Downloaded 24314 tweets
# Downloaded 24414 tweets
# Downloaded 24514 tweets
# Downloaded 24614 tweets
# Downloaded 24708 tweets
# Downloaded 24808 tweets
# Downloaded 24908 tweets
# Downloaded 25001 tweets
# Downloaded 25101 tweets
# Downloaded 25201 tweets
# Downloaded 25301 tweets
# Downloaded 25401 tweets
# Downloaded 25501 tweets
# Downloaded 25601 tweets
# Downloaded 25701 tweets
# Downloaded 25801 tweets
# Downloaded 25901 tweets
# Downloaded 26001 tweets
# Downloaded 26101 tweets
# Downloaded 26201 tweets
# Downloaded 26301 tweets
# Downloaded 26401 tweets
# Downloaded 26501 tweets
# Downloaded 26601 tweets
# Downloaded 26701 tweets
# Downloaded 26801 tweets
# Downloaded 26901 tweets
# Downloaded 27001 tweets
# Downloaded 27101 tweets
# Downloaded 27201 tweets
# Downloaded 27301 tweets
# Downloaded 27401 tweets
# Downloaded 27501 tweets
# Downloaded 27601 tweets
# Downloaded 27701 tweets
# Downloaded 27801 tweets
# Downloaded 27901 tweets
# Downloaded 28001 tweets
# Downloaded 28101 tweets
# Downloaded 28201 tweets
# Downloaded 28301 tweets
# Downloaded 28401 tweets
# Downloaded 28501 tweets
# Downloaded 28601 tweets
# Downloaded 28701 tweets
# Downloaded 28801 tweets
# Downloaded 28901 tweets
# Downloaded 29001 tweets
# Downloaded 29101 tweets
# Downloaded 29201 tweets
# Downloaded 29301 tweets
# Downloaded 29401 tweets
# Downloaded 29501 tweets
# Downloaded 29601 tweets
# Downloaded 29701 tweets
# Downloaded 29801 tweets
# Downloaded 29901 tweets
# Downloaded 30001 tweets
# Downloaded 30101 tweets
# Downloaded 30201 tweets
# Downloaded 30301 tweets
# Downloaded 30401 tweets
# Downloaded 30501 tweets
# Downloaded 30601 tweets
# Downloaded 30701 tweets
# Downloaded 30801 tweets
# Downloaded 30901 tweets
# Downloaded 31001 tweets
# Downloaded 31101 tweets
# Downloaded 31201 tweets
# Downloaded 31301 tweets
# Downloaded 31401 tweets
# Downloaded 31501 tweets
# Downloaded 31601 tweets
# Downloaded 31701 tweets
# Downloaded 31801 tweets
# Downloaded 31901 tweets
# Downloaded 32001 tweets
# Downloaded 32101 tweets
# Downloaded 32104 tweets
# No more tweets found
# Downloaded 32104 tweets

# %%
text = []
for t in all_tweets:
    text.append((t._json['text'], t._json['created_at']))

# %%
text[1]
# Out:
# ('RT @magicmiketrader: Announcing Winner Shortly!! $SPY $TSLA https://t.co/SQgtfGsdau',
#  'Fri May 01 01:19:37 +0000 2020')
